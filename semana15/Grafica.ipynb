# %%
import numpy as np 
import matplotlib.pyplot as plt 
import scipy.constants as cte
# %matplotlib inline

# %%
h=cte.Planck 
k=cte.Boltzmann
c=cte.c

# %%
print (h, k, c)
# Out:
# 6.62607004e-34 1.38064852e-23 299792458.0

# %%
datos=np.loadtxt('IRCF.txt')

# %%
frecuencia=datos[:,0] 
intensidad=datos[:,1] 
barras=datos[:,3]

# %%
plt.errorbar(frecuencia,intensidad,barras, color='red',linewidth=3)
plt.xlabel('Frecuencia (cm^-1)')
plt.ylabel('Intensidad (MJy/sr)')
# Out:
# Text(0,0.5,'Intensidad (MJy/sr)')

# %%
plt.scatter(frecuencia,intensidad,barras)

# %%
T=0
v=0

# %%
I[v,T]=(((h*v**3)/c**2)(1/np.exp((h*v)/k*T)-1))*10**26
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-040b65cc5df9> in <module>()
# ----> 1 I[v,T]=(((h*v**3)/c**2)(1/np.exp((h*v)/k*T)-1))*10**26
#
# TypeError: 'float' object is not callable
